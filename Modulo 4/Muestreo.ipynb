# %% [markdown]
# #![image.png](data:image/png;base64,...)
#
# **Maestría en Ciencia de Datos e Inteligencia Artificial V1E4**
# ##MÓDULO 5 - Análisis Estadístico de Datos
# ##Muestreo Aleatorio Simple
#
# **Universidad Autónoma Gabriel René Moreno de Santa Cruz de la Sierra-Bolivia UAGRM - POSTGRADO**<br/>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

datos = pd.read_csv("/content/diabetes.csv")
datos
# Out:
#       imc  glucosa
# 0    33.6      148
# 1    26.6       85
# 2    23.3      183
# 3    28.1       89
# 4    43.1      137
# ..    ...      ...
# 763  32.9      101
# 764  36.8      122
# 765  26.2      121
# 766  30.1      126
# 767  30.4       93
#
# [768 rows x 2 columns]

# %% [markdown]
# <h2 style="color:purple">Muestreo</h2>

# %%
muestra_personas = datos.sample(frac = 0.10)
muestra_personas
# Out:
#       imc  glucosa
# 765  26.2      121
# 61   32.9      133
# 441  32.2       83
# 215  41.8      151
# 134  21.1       96
# ..    ...      ...
# 173  43.5       79
# 714  29.5      102
# 549  28.5      189
# 691  42.3      158
# 97   20.4       71
#
# [77 rows x 2 columns]

# %% [markdown]
# <h2 style="color:purple">Muestreo de Elementos de una Columna</h2>

# %%
muestra_glucosas = np.random.choice(datos["glucosa"], 10)
muestra_glucosas
# Out:
# array([106, 136,  73, 130, 120,  79, 161,  85, 128,  99])

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
