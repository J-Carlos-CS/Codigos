# %% [markdown]
# #![image.png](data:image/png;base64,...)
#
# **Maestría en Ciencia de Datos e Inteligencia Artificial V1E4**
# ##MÓDULO 5 - Análisis Estadístico de Datos
# ## Pandas
#
# **Universidad Autónoma Gabriel René Moreno de Santa Cruz de la Sierra-Bolivia UAGRM - POSTGRADO**<br/>

# %%
#%pip install pandas
# Out:
# ...
#
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\Hugo Condori\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
# leer los datos csv
df = pd.read_csv('/content/titles.csv')
# df.head() se utiliza para visualizar los primeros 5 registros de  datos
df.head()
# Out:
#                     title  year  rating  votes
# 0          Spanish Fiesta  2019     6.9     29
# 1  La tierra de los toros  2000     5.4     14
# 2           Dama de noche  1993     6.0     25
# 3              Frivolinas  2014     5.6     19
# 4            Mya ga naing  1996     7.5     21

# %%
# para visualizar los primeros 10 registros de datos
df.head(10)
# Out:
#                          title  year  rating  votes
# 0               Spanish Fiesta  2019     6.9     29
# 1       La tierra de los toros  2000     5.4     14
# 2                Dama de noche  1993     6.0     25
# 3                   Frivolinas  2014     5.6     19
# 4                 Mya ga naing  1996     7.5     21
# 5     El huésped del sevillano  1970     6.8     11
# 6               Kate & Leopold  2001     6.4  81684
# 7           Muhomatsu no issho  2008     7.3    108
# 8  Another Time, Another Place  1983     6.5    305
# 9           Let There Be Light  1980     7.5   1799

# %%
# para visualizar los registros que se encuentran al final
df.tail()
# Out:
#                            title  year  rating  votes
# 213660                 Safeguard  2020     3.5    225
# 213661  Il talento del calabrone  2020     5.8   1197
# 213662                     Coven  2020     6.4   4014
# 213663       The Secret of China  2019     3.8     14
# 213664       Kuambil Lagi Hatiku  2019     8.3      6

# %%
# df.tail(10) muestra los ultimos 10 registros
df.tail(10)
# Out:
#                                title  year  rating  votes
# 213655          The Last White Witch  2019     7.7      7
# 213656              Nuestra película  1993     6.2      6
# 213657  The Mystery of a Buryat Lama  2018     4.0      7
# 213658                    Drømmeland  2019     6.4     47
# 213659                 The Rehearsal  2019     7.2      5
# 213660                     Safeguard  2020     3.5    225
# 213661      Il talento del calabrone  2020     5.8   1197
# 213662                         Coven  2020     6.4   4014
# 213663           The Secret of China  2019     3.8     14
# 213664           Kuambil Lagi Hatiku  2019     8.3      6

# %%
df.head(12)
# Out:
#                           title  year  rating  votes
# 0                Spanish Fiesta  2019     6.9     29
# 1        La tierra de los toros  2000     5.4     14
# 2                 Dama de noche  1993     6.0     25
# 3                    Frivolinas  2014     5.6     19
# 4                  Mya ga naing  1996     7.5     21
# 5      El huésped del sevillano  1970     6.8     11
# 6                Kate & Leopold  2001     6.4  81684
# 7            Muhomatsu no issho  2008     7.3    108
# 8   Another Time, Another Place  1983     6.5    305
# 9            Let There Be Light  1980     7.5   1799
# 10                Habla, mudita  1973     6.3    149
# 11                      Nagarik  1977     7.5    202

# %%
# acceder a informacion de los datos cargados en df
# shape
print("el numero de filas y columnas df.shape", df.shape)
print("el numero de filas (# registros) df.shape[0]",df.shape[0])
print("el numero de columnas (# caracteristicas) df.shape[1]",df.shape[1])
# Out:
# el numero de filas y columnas df.shape (213665, 4)
# el numero de filas (# registros) df.shape[0] 213665
# el numero de columnas (# caracteristicas) df.shape[1] 4

# %%
# df.columns: listar el nombre de las columnas
print(df.columns)
# Out:
# Index(['title', 'year', 'rating', 'votes'], dtype='object')

# %%
# cambiar el nombre de las columnas:
nuevas_col = ["Titulo", "año", "rating", "votos"]
df.columns = nuevas_col
df.head()
# Out:
#                    Titulo   año  rating  votos
# 0          Spanish Fiesta  2019     6.9     29
# 1  La tierra de los toros  2000     5.4     14
# 2           Dama de noche  1993     6.0     25
# 3              Frivolinas  2014     5.6     19
# 4            Mya ga naing  1996     7.5     21

# %%
df = pd.read_csv("titles.csv")
df.head()
# Out:
#                     title  year  rating  votes
# 0          Spanish Fiesta  2019     6.9     29
# 1  La tierra de los toros  2000     5.4     14
# 2           Dama de noche  1993     6.0     25
# 3              Frivolinas  2014     5.6     19
# 4            Mya ga naing  1996     7.5     21

# %%
df2 = pd.read_csv("cast.csv",delimiter="|")

# %%
df2.head()
# Out:
#              name                   title  year  rating  votes
# 0     Ève Francis          Spanish Fiesta  2019     6.9     29
# 1  Gabriel Gabrio          Spanish Fiesta  2019     6.9     29
# 2    Jean Toulout          Spanish Fiesta  2019     6.9     29
# 3    Gaston Modot          Spanish Fiesta  2019     6.9     29
# 4  Antonio Cañero  La tierra de los toros  2000     5.4     14

# %%
# Metodos comunes de procesamiento de los datos
# acceso a una columna => votes
print(df["votes"])
# Out:
# 0           29
# 1           14
# 2           25
# 3           19
# 4           21
#           ...
# 213660     225
# 213661    1197
# 213662    4014
# 213663      14
# 213664       6
# Name: votes, Length: 213665, dtype: int64

# %%
serie_pd = df["votes"]
df_pd    = df[["votes"]]
print(serie_pd)
# Out:
# 0           29
# 1           14
# 2           25
# 3           19
# 4           21
#           ...
# 213660     225
# 213661    1197
# 213662    4014
# 213663      14
# 213664       6
# Name: votes, Length: 213665, dtype: int64

# %%
print(df_pd)
# Out:
#         votes
# 0          29
# 1          14
# 2          25
# 3          19
# 4          21
# ...       ...
# 213660    225
# 213661   1197
# 213662   4014
# 213663     14
# 213664      6
#
# [213665 rows x 1 columns]

# %%
print("la variable serie_pd tiene como tipo: ",type(serie_pd))
print("la variable df_pd tiene como tipo: ",type(df_pd))
# Out:
# la variable serie_pd tiene como tipo:  <class 'pandas.core.series.Series'>
# la variable df_pd tiene como tipo:  <class 'pandas.core.frame.DataFrame'>

# %%
df_pd2 = df[["votes","year"]]
df_pd2.head()
# Out:
#    votes  year
# 0     29  2019
# 1     14  2000
# 2     25  1993
# 3     19  2014
# 4     21  1996

# %%
# problemas en lectura de datos
df3 = pd.read_csv("titles copy.csv")
df3.head()
# Out:
# C:\Users\Hugo Condori\AppData\Local\Temp\ipykernel_19904\170040033.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("titles copy.csv")
#                     title  year  rating  votes
# 0                 sf       2019     6.9     29
# 1  La tierra de los toros  2000     5.4     14
# 2           Dama de noche           6.0     25
# 3              Frivolinas  2014     5.6     19
# 4            Mya ga naing  1996     7.5     21

# %%
df3["year"]
# Out:
# 0         2019
# 1         2000
# 2
# 3         2014
# 4         1996
#           ...
# 213660    2020
# 213661    2020
# 213662    2020
# 213663    2019
# 213664    2019
# Name: year, Length: 213665, dtype: object

# %%
# obtener el tipo de datos de una columna
df["year"].dtype
# Out:
# dtype('int64')

# %%
votos_serie =df["votes"]
print(votos_serie)
# Out:
# 0           29
# 1           14
# 2           25
# 3           19
# 4           21
#           ...
# 213660     225
# 213661    1197
# 213662    4014
# 213663      14
# 213664       6
# Name: votes, Length: 213665, dtype: int64

# %%
print(df["votes"].sort_values(ascending=False))
# Out:
# 26541     2476378
# 80445     2430487
# 114624    2181019
# 33888     1950566
# 26393     1916896
#            ...
# 39225           5
# 60098           5
# 116682          5
# 195360          5
# 177382          5
# Name: votes, Length: 213665, dtype: int64

# %%
serie2 = df["votes"].sort_values(ascending=False)

# %%
print(serie2.sort_index(ascending=False))
# Out:
# 213664       6
# 213663      14
# 213662    4014
# 213661    1197
# 213660     225
#           ...
# 4           21
# 3           19
# 2           25
# 1           14
# 0           29
# Name: votes, Length: 213665, dtype: int64

# %%
# Acceso a elementos con un indice dado
df.iloc[26541]
# Out:
# title     The Shawshank Redemption
# year                          1994
# rating                         9.3
# votes                      2476378
# Name: 26541, dtype: object

# %%
df.head()
# Out:
#                     title  year  rating  votes
# 0          Spanish Fiesta  2019     6.9     29
# 1  La tierra de los toros  2000     5.4     14
# 2           Dama de noche  1993     6.0     25
# 3              Frivolinas  2014     5.6     19
# 4            Mya ga naing  1996     7.5     21

# %%
serie3 = df["title"]

# %%
serie3
# Out:
# 0                   Spanish Fiesta
# 1           La tierra de los toros
# 2                    Dama de noche
# 3                       Frivolinas
# 4                     Mya ga naing
#                     ...
# 213660                   Safeguard
# 213661    Il talento del calabrone
# 213662                       Coven
# 213663         The Secret of China
# 213664         Kuambil Lagi Hatiku
# Name: title, Length: 213665, dtype: object

# %%
# la respuesta a esta busqueda son variables booleanas
df["title"].str.contains("The Karate Kid")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 213660    False
# 213661    False
# 213662    False
# 213663    False
# 213664    False
# Name: title, Length: 213665, dtype: bool

# %%
filtro = df["title"].str.contains("The Karate Kid")
print(df[filtro])
# Out:
#                           title  year  rating   votes
# 13570            The Karate Kid  1984     7.3  209089
# 15717    The Karate Kid Part II  1986     6.1   84216
# 19353   The Karate Kid Part III  1989     5.3   57583
# 101553           The Karate Kid  2010     6.2  171641

# %%
# creacion de filtros con datos numericos
filtro2 = df["rating"]>9.5
print(df[filtro2])
# Out:
#                                   title  year  rating  votes
# 3016             Always a New Beginning  1974     9.6     15
# 22570                     All I Know Is  1992    10.0      5
# 55577                          The Want  2001     9.8      9
# 74078                The People's Story  2000     9.6     20
# 77226                    Indocumentados  2004     9.8     15
# ...                                 ...   ...     ...    ...
# 212476           The Gods as My Friends  2019     9.8     14
# 212502            The Bailey Experience  2019     9.6      6
# 212706  Kaye Ballard - The Show Goes On  2019    10.0    193
# 212935           As If They Were Angels  2018     9.7      7
# 213487                         Route 66  2018     9.7      9
#
# [197 rows x 4 columns]

# %%
# filtros con mas condiciones
filtro3 = (df["rating"]>9) & (df["year"]>2014) & (df["votes"]>100)
print(df[filtro3])
# Out:
#                                             title  year  rating  votes
# 91808                       Ratne price sa Kosara  2019     9.5    146
# 92030                             Soorarai Pottru  2020     9.1  90625
# 92677                                Sardar Udham  2021     9.2  15941
# 93403   The Dark Knight: The Ballad of the N Word  2018     9.2    105
# 94766                               Russian death  2019     9.2    154
# ...                                           ...   ...     ...    ...
# 207842                                       Toma  2021     9.2   6103
# 209782         The Least Professional Broadcaster  2018     9.2    141
# 212415                               Gho Gho Rani  2019     9.3    194
# 212706            Kaye Ballard - The Show Goes On  2019    10.0    193
# 213249                        Moscow we will lose  2019     9.2    139
#
# [99 rows x 4 columns]

# %%
# condicion or
filtro4 = (df["rating"]>9.5) | (df["votes"]>10000)
print(df[filtro4])
# Out:
#                                     title  year  rating   votes
# 6                          Kate & Leopold  2001     6.4   81684
# 213             Two Mules for Sister Sara  1970     7.0   26569
# 216     The Bird with the Crystal Plumage  1970     7.2   19881
# 252                               Airport  1970     6.6   18430
# 280                        The Aristocats  1970     7.1   98736
# ...                                   ...   ...     ...     ...
# 213438                           Holidate  2020     6.1   53296
# 213487                           Route 66  2018     9.7       9
# 213561                       I Care a Lot  2020     6.3  116135
# 213585                    Coffee & Kareem  2020     5.1   12848
# 213598                             Kaithi  2019     8.5   17753
#
# [9012 rows x 4 columns]

# %%
df.head()
# Out:
#                     title  year  rating  votes
# 0          Spanish Fiesta  2019     6.9     29
# 1  La tierra de los toros  2000     5.4     14
# 2           Dama de noche  1993     6.0     25
# 3              Frivolinas  2014     5.6     19
# 4            Mya ga naing  1996     7.5     21

# %%
# adicionar nuevas columnas al dataframe
df["decada"] = df["year"]//10*10
df.head()
# Out:
#                     title  year  rating  votes  decada
# 0          Spanish Fiesta  2019     6.9     29    2010
# 1  La tierra de los toros  2000     5.4     14    2000
# 2           Dama de noche  1993     6.0     25    1990
# 3              Frivolinas  2014     5.6     19    2010
# 4            Mya ga naing  1996     7.5     21    1990

# %%
# quisiera obtener el numero de peliculas lanzada en cada decada
# 2010 =>  ...
df["decada"].value_counts()
# Out:
# 2010    87847
# 2000    46006
# 1990    25676
# 1980    22409
# 1970    19902
# 2020    11825
# Name: decada, dtype: int64

# %%
# organizacion de los datos con metodos utilizados en cadena
df["decada"].value_counts().sort_index()
# Out:
# 1970    19902
# 1980    22409
# 1990    25676
# 2000    46006
# 2010    87847
# 2020    11825
# Name: decada, dtype: int64

# %%
df["decada"].value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# %pip install matplotlib

# %%
df2.head()
# Out:
#              name                   title  year  rating  votes
# 0     Ève Francis          Spanish Fiesta  2019     6.9     29
# 1  Gabriel Gabrio          Spanish Fiesta  2019     6.9     29
# 2    Jean Toulout          Spanish Fiesta  2019     6.9     29
# 3    Gaston Modot          Spanish Fiesta  2019     6.9     29
# 4  Antonio Cañero  La tierra de los toros  2000     5.4     14

# %%
# adiciona
df2["decada"]= df2["year"]//10*10
# eliminar la columna year
df2.drop(["year"],axis=1,inplace=True)
df2.head()
# Out:
#              name                   title  rating  votes  decada
# 0     Ève Francis          Spanish Fiesta     6.9     29    2010
# 1  Gabriel Gabrio          Spanish Fiesta     6.9     29    2010
# 2    Jean Toulout          Spanish Fiesta     6.9     29    2010
# 3    Gaston Modot          Spanish Fiesta     6.9     29    2010
# 4  Antonio Cañero  La tierra de los toros     5.4     14    2000

# %%
df2.head()
# Out:
#              name                   title  rating  votes  decada
# 0     Ève Francis          Spanish Fiesta     6.9     29    2010
# 1  Gabriel Gabrio          Spanish Fiesta     6.9     29    2010
# 2    Jean Toulout          Spanish Fiesta     6.9     29    2010
# 3    Gaston Modot          Spanish Fiesta     6.9     29    2010
# 4  Antonio Cañero  La tierra de los toros     5.4     14    2000

# %%
df2["rating"]= df2["rating"]*100
df2.head()
# Out:
#              name                   title  rating  votes  decada
# 0     Ève Francis          Spanish Fiesta   690.0     29    2010
# 1  Gabriel Gabrio          Spanish Fiesta   690.0     29    2010
# 2    Jean Toulout          Spanish Fiesta   690.0     29    2010
# 3    Gaston Modot          Spanish Fiesta   690.0     29    2010
# 4  Antonio Cañero  La tierra de los toros   540.0     14    2000

# %%
df.head()
# Out:
#                     title  year  rating  votes  decada
# 0          Spanish Fiesta  2019     6.9     29    2010
# 1  La tierra de los toros  2000     5.4     14    2000
# 2           Dama de noche  1993     6.0     25    1990
# 3              Frivolinas  2014     5.6     19    2010
# 4            Mya ga naing  1996     7.5     21    1990

# %%
df.to_csv("titlesv2.csv")

# %%
# indexacion
df.head()
# Out:
#                     title  year  rating  votes  decada
# 0          Spanish Fiesta  2019     6.9     29    2010
# 1  La tierra de los toros  2000     5.4     14    2000
# 2           Dama de noche  1993     6.0     25    1990
# 3              Frivolinas  2014     5.6     19    2010
# 4            Mya ga naing  1996     7.5     21    1990

# %%
df.set_index("title",inplace=True)
df.head()
# Out:
#                         year  rating  votes  decada
# title
# Spanish Fiesta          2019     6.9     29    2010
# La tierra de los toros  2000     5.4     14    2000
# Dama de noche           1993     6.0     25    1990
# Frivolinas              2014     5.6     19    2010
# Mya ga naing            1996     7.5     21    1990

# %%
# busqueda de datos en funcion al indice:
# df.iloc
df.iloc[3]
# Out:
# year      2014.0
# rating       5.6
# votes       19.0
# decada    2010.0
# Name: Frivolinas, dtype: float64

# %%
# df.loc
df.loc["Frivolinas"]
# Out:
# year      2014.0
# rating       5.6
# votes       19.0
# decada    2010.0
# Name: Frivolinas, dtype: float64

# %%
df.head()
# Out:
#                         year  rating  votes  decada
# title
# Spanish Fiesta          2019     6.9     29    2010
# La tierra de los toros  2000     5.4     14    2000
# Dama de noche           1993     6.0     25    1990
# Frivolinas              2014     5.6     19    2010
# Mya ga naing            1996     7.5     21    1990

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                     title  year  rating  votes  decada
# 0          Spanish Fiesta  2019     6.9     29    2010
# 1  La tierra de los toros  2000     5.4     14    2000
# 2           Dama de noche  1993     6.0     25    1990
# 3              Frivolinas  2014     5.6     19    2010
# 4            Mya ga naing  1996     7.5     21    1990
