# %% [markdown]
# #![image.png](data:image/png;base64,...)
#
# **Maestría en Ciencia de Datos e Inteligencia Artificial V1E4**
# ##MÓDULO 5 - Análisis Estadístico de Datos
# ##Regresión lineal
#
# **Universidad Autónoma Gabriel René Moreno de Santa Cruz de la Sierra-Bolivia UAGRM - POSTGRADO**<br/>
# **Regresión lineal - Datos de producción**<br/>

# %%
# Importar librerias
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
# Cargar datos
df = pd.read_excel("/content/datos_producción.xlsx")
df.head()
# Out:
#    Semana  Horas Trabajadas  Horas Descanso  Productos Terminados
# 0       1                42               2             28.925481
# 1       2                45               3             30.570058
# 2       3                30               2             21.132880
# 3       4                33               2             21.798530
# 4       5                33               3             19.343444

# %%
# Seleccionar variables
variable_x = "Horas Trabajadas"
variable_y = "Productos Terminados"

# %%
# Generar análisis
modelo = LinearRegression()
modelo.fit(df[[variable_x]], df[variable_y])
print ('Ecuación de la recta: y = ', round(modelo.coef_[0],3),'x + ', round(modelo.intercept_,3))#obtenemos la ecuación de la recta
print ('Coeficiente de correlación: ', round(np.corrcoef(df[variable_x], df[variable_y])[0,1], 3))#obtenemos el coeficiente de correlación
print ('Coeficiente de determinación: ', round(r2_score(df[variable_y], modelo.predict(df[[variable_x]])), 3))#obtenemos el coeficiente de determinación
# Gráfica con intervalo de confianza
sns.regplot(x=df[variable_x], y=df[variable_y], ci=95, line_kws={"color": "red"}, scatter_kws={"color": "black"})
plt.title('Regresión lineal simple con intervalo de confianza al 95%')
plt.show()
# Out:
# Ecuación de la recta: y =  0.494 x +  5.166
# Coeficiente de correlación:  0.889
# Coeficiente de determinación:  0.79

# %%
# Generar PREDICCIÓN
dato_predictor = 15

horas_trabajadas_nuevas = pd.DataFrame([dato_predictor], columns=[variable_x])  # Convertir a DataFrame
autos_producidos_prediccion = modelo.predict(horas_trabajadas_nuevas)
print('La predicción de autos producidos para', horas_trabajadas_nuevas.iloc[0][0], 'horas trabajadas es', round(autos_producidos_prediccion[0], 3))
# Out:
# La predicción de autos producidos para 15 horas trabajadas es 12.578
# /tmp/ipython-input-3298879014.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('La predicción de autos producidos para', horas_trabajadas_nuevas.iloc[0][0], 'horas trabajadas es', round(autos_producidos_prediccion[0], 3))
